# %%
import numpy as np
import pyvista as pv

case_name = "case6"
# mesh_name = "mesh_square"
# mesh_name = "mesh_block_pipe_refined"
mesh_name = "mesh_square_QUAD8"

sol_ngsolve = pv.read(f"output/{case_name}/{case_name}_ngsolve.vtu")
sol_ngsolve = sol_ngsolve["sol"]
sol_fenicsx = pv.read(f"output/{case_name}/{case_name}_fenics.vtu")
sol_fenicsx = sol_fenicsx["sol"]
sol_moose = pv.read(f"output/{case_name}/{case_name}_moose.vtu")
sol_moose = sol_moose["sol"]

# NGSolve and FEniCS

abs_error = np.abs(sol_ngsolve - sol_fenicsx)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print (f"Case: {case_name}")
print("")
print(f"  * Max. absolute error between NGSolve and FEniCS : {abs_error_max:.3e}.")
print(f"  * Avg. absolute error between NGSolve and FEniCS : {abs_error_mean:.3e}.")

mesh_path = f"meshes/{mesh_name}.msh"

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_fenics.vtu")

# NGSolve and MOOSE

mesh_path = f"meshes/{mesh_name}.msh"

abs_error = np.abs(sol_ngsolve - sol_moose)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print(f"  * Max. absolute error between NGSolve and MOOSE : {abs_error_max:.3e}.")
print(f"  * Avg. absolute error between NGSolve and MOOSE : {abs_error_mean:.3e}.")

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_moose.vtu")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 12
#      10 sol_ngsolve = sol_ngsolve["sol"]
#      11 sol_fenicsx = pv.read(f"output/{case_name}/{case_name}_fenics.vtu")
# ---> 12 sol_fenicsx = sol_fenicsx["sol"]
#      13 sol_moose = pv.read(f"output/{case_name}/{case_name}_moose.vtu")
#      14 sol_moose = sol_moose["sol"]
#
# File ~/anaconda3/envs/ngsolve-env/lib/python3.11/site-packages/pyvista/core/dataset.py:1478, in DataSet.__getitem__(self, index)
#    1473     msg = (  # type: ignore[unreachable]
#    1474         f'Index ({index}) not understood.'
#    1475         ' Index must be a string name or a tuple of string name and string preference.'
#    1476     )
#    1477     raise KeyError(msg)
# -> 1478 return self.get_array(name, preference=preference)
#
# ...

# %%
import numpy as np
import pyvista as pv

case_name = "case5"
mesh_name = "mesh_block_pipe_refined"

sol_ngsolve = pv.read(f"output/{case_name}/{case_name}_ngsolve.vtu")
sol_ngsolve = sol_ngsolve["sol"]
sol_moose = pv.read(f"output/{case_name}/{case_name}_moose.vtu")
sol_moose = sol_moose["sol"]

# NGSolve and MOOSE

res = pv.read(mesh_path)

mesh_path = f"meshes/{mesh_name}.msh"

abs_error = np.abs(sol_ngsolve - sol_moose)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print(f"Max. absolute error between NGSolve and MOOSE : {abs_error_max:.3e}.")
print(f"Avg. absolute error between NGSolve and MOOSE : {abs_error_mean:.3e}.")

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_moose.vtu")
# Out:
# Max. absolute error between NGSolve and MOOSE : 2.382e-04.
# Avg. absolute error between NGSolve and MOOSE : 2.211e-04.

# %%
import numpy as np
import pyvista as pv

case_name = "case6"
# mesh_name = "mesh_square"
mesh_name = "mesh_square_QUAD8"

sol_fenicsx = pv.read(f"output/{case_name}/{case_name}_fenics.vtu")
sol_fenicsx = sol_fenicsx["disp"]
sol_moose = pv.read(f"output/{case_name}/{case_name}_moose.vtu")
sol_moose = sol_moose["disp"]

# MOOSE and FEniCS

abs_error = np.abs(sol_moose - sol_fenicsx)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print (f"Case: {case_name}")
print("")
print(f"  * Max. absolute error between MOOSE and FEniCS : {abs_error_max:.3e}.")
print(f"  * Avg. absolute error between MOOSE and FEniCS : {abs_error_mean:.3e}.")

mesh_path = f"meshes/{mesh_name}.msh"

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_fenics.vtu")
# Out:
# Case: case6
#
#   * Max. absolute error between MOOSE and FEniCS : 5.452e-10.
#   * Avg. absolute error between MOOSE and FEniCS : 1.461e-10.

# %%
import numpy as np
import pyvista as pv

case_name = "case6"
# mesh_name = "mesh_square"
# mesh_name = "mesh_block_pipe_refined"
mesh_name = "mesh_square_QUAD8"

sol_ngsolve = pv.read(f"output/{case_name}/{case_name}_ngsolve.vtu")
sol_ngsolve = sol_ngsolve["disp"]
sol_fenicsx = pv.read(f"output/{case_name}/{case_name}_fenics.vtu")
sol_fenicsx = sol_fenicsx["disp"]
sol_moose = pv.read(f"output/{case_name}/{case_name}_moose.vtu")
sol_moose = sol_moose["disp"]

# NGSolve and FEniCS

abs_error = np.abs(sol_ngsolve - sol_fenicsx)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print (f"Case: {case_name}")
print("")
print(f"  * Max. absolute error between NGSolve and FEniCS : {abs_error_max:.3e}.")
print(f"  * Avg. absolute error between NGSolve and FEniCS : {abs_error_mean:.3e}.")

mesh_path = f"meshes/{mesh_name}.msh"

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_fenics.vtu")

# NGSolve and MOOSE

mesh_path = f"meshes/{mesh_name}.msh"

abs_error = np.abs(sol_ngsolve - sol_moose)

abs_error_max = np.max(abs_error)
abs_error_mean = np.mean(abs_error)

print(f"  * Max. absolute error between NGSolve and MOOSE : {abs_error_max:.3e}.")
print(f"  * Avg. absolute error between NGSolve and MOOSE : {abs_error_mean:.3e}.")

res = pv.read(mesh_path)

res['absolute_error_ngsolve_fenics'] = abs_error

res.save(f"output/{case_name}/{case_name}_error_ngsolve_moose.vtu")
# Out:
# Case: case6
#
#   * Max. absolute error between NGSolve and FEniCS : 2.356e-07.
#   * Avg. absolute error between NGSolve and FEniCS : 7.447e-08.
#
#   * Max. absolute error between NGSolve and MOOSE : 1.572e-06.
#   * Avg. absolute error between NGSolve and MOOSE : 9.886e-08.
