# %%
import time
from pathlib import Path

#pyvale imports
import pyvale.dataset as dataset
from pyvale.mooseherder import (MooseConfig,
                                MooseRunner)

# %%
config = {'main_path': Path.home()/ 'moose',
          'app_path': Path.home() / 'proteus',
          'app_name': 'proteus-opt'}
moose_config = MooseConfig(config)

# %%
moose_runner = MooseRunner(moose_config)

moose_runner.set_run_opts(n_tasks = 1,
                          n_threads = 8,
                          redirect_out = False)

# %%
moose_input = Path("input/case01.i")
moose_runner.set_input_file(moose_input)

# %%
print(moose_runner.get_arg_list())
print()
# Out:
# ['proteus-opt', '--n-threads=8', '-i', 'case01.i']

# %%
start_time = time.perf_counter()
moose_runner.run()
run_time = time.perf_counter() - start_time

print()
print("-"*80)
print(f'MOOSE run time = {run_time:.3f} seconds')
print("-"*80)
print()
# Out:
# Framework Information:
# MOOSE Version:           git commit aea74f0345 on 2025-11-13
# LibMesh Version:         910736a3a20aded528c3ba99371ce65980dc8e2c
# PETSc Version:           3.24.0
# SLEPc Version:           3.24.0
# Current Time:            Tue Nov 18 15:23:28 2025
# Executable Timestamp:    Mon Nov 17 09:18:38 2025
#
# Input File(s):
#   /home/wiera/Documents/compare-fem/input/case01.i
#
# Command Line Argument(s):
#   --n-threads=8
#
# Checkpoint:
#   Wall Time Interval:      Every 3600 s
#   User Checkpoint:         Disabled
#   # Checkpoints Kept:      2
#   Execute On:              TIMESTEP_END
#
# Parallelism:
#   Num Processors:          1
#   Num Threads:             8
#
# Mesh:
#   Parallel Type:           replicated
#   Mesh Dimension:          2
#   Spatial Dimension:       2
#   Nodes:                   231
#   Elems:                   200
#   Num Subdomains:          1
#
# Nonlinear System:
#   Num DOFs:                231
#   Num Local DOFs:          231
#   Variables:               "temperature"
#   Finite Element Types:    "LAGRANGE"
#   Approximation Orders:    "FIRST"
#
# Execution Information:
#   Executioner:             Steady
#   Solver Mode:             Preconditioned JFNK
#
# Postprocessor Values:
# +----------------+----------------+----------------+
# | time           | avg_temp       | max_temp       |
# +----------------+----------------+----------------+
# |   0.000000e+00 |   0.000000e+00 |   0.000000e+00 |
# +----------------+----------------+----------------+
#
#  0 Nonlinear |R| = 7.705518e+03
#       0 Linear |R| = 7.705518e+03
#       1 Linear |R| = 3.864315e+03
#       2 Linear |R| = 2.720761e+03
#       3 Linear |R| = 2.375621e+03
#       4 Linear |R| = 2.060299e+03
#       5 Linear |R| = 1.853719e+03
#       6 Linear |R| = 1.658783e+03
#       7 Linear |R| = 1.120435e+03
#       8 Linear |R| = 3.001819e+02
#       9 Linear |R| = 8.135620e+01
#      10 Linear |R| = 2.497130e+01
#      11 Linear |R| = 8.829051e+00
#      12 Linear |R| = 2.946348e+00
#      13 Linear |R| = 1.027110e+00
#      14 Linear |R| = 4.047377e-01
#      15 Linear |R| = 1.513850e-01
#      16 Linear |R| = 4.203710e-02
#  1 Nonlinear |R| = 6.851402e-02
#       0 Linear |R| = 6.851402e-02
#       1 Linear |R| = 1.334483e-02
#       2 Linear |R| = 5.941784e-03
#       3 Linear |R| = 3.282642e-03
#       4 Linear |R| = 2.170128e-03
#       5 Linear |R| = 1.923990e-03
#       6 Linear |R| = 1.788935e-03
#       7 Linear |R| = 1.530769e-03
#       8 Linear |R| = 1.218574e-03
#       9 Linear |R| = 7.478428e-04
#      10 Linear |R| = 4.227894e-04
#      11 Linear |R| = 1.773096e-04
#      12 Linear |R| = 3.580065e-05
#      13 Linear |R| = 7.755850e-06
#      14 Linear |R| = 2.128159e-06
#      15 Linear |R| = 7.229946e-07
#      16 Linear |R| = 1.885223e-07
#  2 Nonlinear |R| = 2.181378e-07
#  Solve Converged!
#
# Postprocessor Values:
# +----------------+----------------+----------------+
# | time           | avg_temp       | max_temp       |
# +----------------+----------------+----------------+
# |   0.000000e+00 |   0.000000e+00 |   0.000000e+00 |
# |   1.000000e+00 |   8.910417e+01 |   1.542083e+02 |
# +----------------+----------------+----------------+
#
#
# --------------------------------------------------------------------------------
# MOOSE run time = 2.330 seconds
# --------------------------------------------------------------------------------
